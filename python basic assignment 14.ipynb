# %% [markdown]
# ## 1. What does RGBA stand for?

# %% [markdown]
# An RGB color value is specified with: rgb(red, green, blue). Each parameter (red, green, and blue) defines the intensity of the color and can be an integer between 0 and 255 or a percentage value (from 0% to 100%).
# Red value of its RGB is 55, Green value is 118 and blue value is 171.

# %% [markdown]
# ## 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
from PIL import Image

im = Image.open("kunal.png")
im_alpha = im.convert('RGBA')
Pixels = list(im.getdata())

ImageColor.getcolor('CornflowerBlue', 'RGBA')

# %% [markdown]
# ## 3. What is a box tuple, and how does it work?

# %% [markdown]
# A box tuple is a tuple value of four integers: the left-edge x-coordinate, the top-edge y-coordinate, the width, and the height, respectively.

# %% [markdown]
# ## 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
img = Image.open('kunal.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=741x392 at 0x156DE3FB520>

# %%
img.size
# Out:
# (741, 392)

# %% [markdown]
# ## 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %% [markdown]
# img.crop((0, 50, 50, 50))

# %% [markdown]
# ## 6. After making changes to an Image object, how could you save it as an image file?

# %% [markdown]
# img.crop((0, 50, 50, 50))

# %% [markdown]
# ## 7. What module contains Pillow’s shape-drawing code?

# %%
img.crop((0, 50, 50, 50))
img.save('newimg.jpg')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=741x392 at 0x156DE3FB520>

# %% [markdown]
# ## 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [markdown]
# ImageDraw module contains code to draw on images.ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). They are returned by passing the Image object to the ImageDraw.Draw() function.
